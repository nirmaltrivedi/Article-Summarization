# %%
import spacy
from spacy.lang.en.stop_words import STOP_WORDS
from string import punctuation
from heapq import nlargest

# %%
# spacy.cli.download('en_core_web_sm')

# %%
text = """Anthony Edward Stark, more commonly known as Tony Stark, is a fictional character primarily portrayed by Robert Downey Jr. in the Marvel Cinematic Universe (MCU) media franchise—based on the Marvel Comics character of the same name—commonly known by his alias, Iron Man. Stark is initially depicted as an industrialist, genius inventor, and playboy who is CEO of Stark Industries. Initially the chief weapons manufacturer for the U.S. military, he has a change of heart and redirects his technical knowledge into the creation of mechanized suits of armor which he uses to defend against those that would threaten peace around the world. He becomes a founding member and leader of the Avengers. Following his failed Ultron Program, the internal conflict within the Avengers due to the Sokovia Accords, and Thanos successfully erasing half of all life in the Blip, Stark retires, marries Pepper Potts, and they have a daughter named Morgan. However, Stark rejoins the Avengers on a final mission to undo Thanos' actions. He creates time travel, and the Avengers successfully restore trillions of lives across the universe. However, Stark inevitably sacrifices his life to defeat Thanos and his army. Stark chooses Peter Parker as a successor."""

# %%
stopwords = list(STOP_WORDS)
nlp = spacy.load('en_core_web_sm')
doc = nlp(text)
doc
# Out:
# Anthony Edward Stark, more commonly known as Tony Stark, is a fictional character primarily portrayed by Robert Downey Jr. in the Marvel Cinematic Universe (MCU) media franchise—based on the Marvel Comics character of the same name—commonly known by his alias, Iron Man. Stark is initially depicted as an industrialist, genius inventor, and playboy who is CEO of Stark Industries. Initially the chief weapons manufacturer for the U.S. military, he has a change of heart and redirects his technical knowledge into the creation of mechanized suits of armor which he uses to defend against those that would threaten peace around the world. He becomes a founding member and leader of the Avengers. Following his failed Ultron Program, the internal conflict within the Avengers due to the Sokovia Accords, and Thanos successfully erasing half of all life in the Blip, Stark retires, marries Pepper Potts, and they have a daughter named Morgan. However, Stark rejoins the Avengers on a final mission to undo Thanos' actions. He creates time travel, and the Avengers successfully restore trillions of lives across the universe. However, Stark inevitably sacrifices his life to defeat Thanos and his army. Stark chooses Peter Parker as a successor.

# %%
tokens = [tokens.text for tokens in doc]
tokens
# Out:
# ['Anthony',
#  'Edward',
#  'Stark',
#  ',',
#  'more',
#  'commonly',
#  'known',
#  'as',
#  'Tony',
#  'Stark',
#  ',',
#  'is',
#  'a',
#  'fictional',
#  'character',
#  'primarily',
#  'portrayed',
#  'by',
#  'Robert',
#  'Downey',
#  'Jr.',
#  'in',
#  'the',
#  'Marvel',
#  'Cinematic',
#  'Universe',
#  '(',
#  'MCU',
#  ')',
#  'media',
#  'franchise',
#  '—',
#  'based',
#  'on',
#  'the',
#  'Marvel',
#  'Comics',
#  'character',
#  'of',
#  'the',
#  'same',
#  'name',
#  '—',
#  'commonly',
#  'known',
#  'by',
#  'his',
#  'alias',
#  ',',
#  'Iron',
#  'Man',
#  '.',
#  'Stark',
#  'is',
#  'initially',
#  'depicted',
#  'as',
#  'an',
#  'industrialist',
#  ',',
#  'genius',
#  'inventor',
#  ',',
#  'and',
#  'playboy',
#  'who',
#  'is',
#  'CEO',
#  'of',
#  'Stark',
#  'Industries',
#  '.',
#  'Initially',
#  'the',
#  'chief',
#  'weapons',
#  'manufacturer',
#  'for',
#  'the',
#  'U.S.',
#  'military',
#  ',',
#  'he',
#  'has',
#  'a',
#  'change',
#  'of',
#  'heart',
#  'and',
#  'redirects',
#  'his',
#  'technical',
#  'knowledge',
#  'into',
#  'the',
#  'creation',
#  'of',
#  'mechanized',
#  'suits',
#  'of',
#  'armor',
#  'which',
#  'he',
#  'uses',
#  'to',
#  'defend',
#  'against',
#  'those',
#  'that',
#  'would',
#  'threaten',
#  'peace',
#  'around',
#  'the',
#  'world',
#  '.',
#  'He',
#  'becomes',
#  'a',
#  'founding',
#  'member',
#  'and',
#  'leader',
#  'of',
#  'the',
#  'Avengers',
#  '.',
#  'Following',
#  'his',
#  'failed',
#  'Ultron',
#  'Program',
#  ',',
#  'the',
#  'internal',
#  'conflict',
#  'within',
#  'the',
#  'Avengers',
#  'due',
#  'to',
#  'the',
#  'Sokovia',
#  'Accords',
#  ',',
#  'and',
#  'Thanos',
#  'successfully',
#  'erasing',
#  'half',
#  'of',
#  'all',
#  'life',
#  'in',
#  'the',
#  'Blip',
#  ',',
#  'Stark',
#  'retires',
#  ',',
#  'marries',
#  'Pepper',
#  'Potts',
#  ',',
#  'and',
#  'they',
#  'have',
#  'a',
#  'daughter',
#  'named',
#  'Morgan',
#  '.',
#  'However',
#  ',',
#  'Stark',
#  'rejoins',
#  'the',
#  'Avengers',
#  'on',
#  'a',
#  'final',
#  'mission',
#  'to',
#  'undo',
#  'Thanos',
#  "'",
#  'actions',
#  '.',
#  'He',
#  'creates',
#  'time',
#  'travel',
#  ',',
#  'and',
#  'the',
#  'Avengers',
#  'successfully',
#  'restore',
#  'trillions',
#  'of',
#  'lives',
#  'across',
#  'the',
#  'universe',
#  '.',
#  'However',
#  ',',
#  'Stark',
#  'inevitably',
#  'sacrifices',
#  'his',
#  'life',
#  'to',
#  'defeat',
#  'Thanos',
#  'and',
#  'his',
#  'army',
#  '.',
#  'Stark',
#  'chooses',
#  'Peter',
#  'Parker',
#  'as',
#  'a',
#  'successor',
#  '.']

# %%
word_freq = {}
for word in doc:
    if word.text.lower() not in stopwords and word.text.lower() not in punctuation:
        if word.text not in word_freq.keys():
            word_freq[word.text] = 1
        else:
            word_freq[word.text] += 1
word_freq
# Out:
# {'Anthony': 1,
#  'Edward': 1,
#  'Stark': 8,
#  'commonly': 2,
#  'known': 2,
#  'Tony': 1,
#  'fictional': 1,
#  'character': 2,
#  'primarily': 1,
#  'portrayed': 1,
#  'Robert': 1,
#  'Downey': 1,
#  'Jr.': 1,
#  'Marvel': 2,
#  'Cinematic': 1,
#  'Universe': 1,
#  'MCU': 1,
#  'media': 1,
#  'franchise': 1,
#  '—': 2,
#  'based': 1,
#  'Comics': 1,
#  'alias': 1,
#  'Iron': 1,
#  'Man': 1,
#  'initially': 1,
#  'depicted': 1,
#  'industrialist': 1,
#  'genius': 1,
#  'inventor': 1,
#  'playboy': 1,
#  'CEO': 1,
#  'Industries': 1,
#  'Initially': 1,
#  'chief': 1,
#  'weapons': 1,
#  'manufacturer': 1,
#  'U.S.': 1,
#  'military': 1,
#  'change': 1,
#  'heart': 1,
#  'redirects': 1,
#  'technical': 1,
#  'knowledge': 1,
#  'creation': 1,
#  'mechanized': 1,
#  'suits': 1,
#  'armor': 1,
#  'uses': 1,
#  'defend': 1,
#  'threaten': 1,
#  'peace': 1,
#  'world': 1,
#  'founding': 1,
#  'member': 1,
#  'leader': 1,
#  'Avengers': 4,
#  'Following': 1,
#  'failed': 1,
#  'Ultron': 1,
#  'Program': 1,
#  'internal': 1,
#  'conflict': 1,
#  'Sokovia': 1,
#  'Accords': 1,
#  'Thanos': 3,
#  'successfully': 2,
#  'erasing': 1,
#  'half': 1,
#  'life': 2,
#  'Blip': 1,
#  'retires': 1,
#  'marries': 1,
#  'Pepper': 1,
#  'Potts': 1,
#  'daughter': 1,
#  'named': 1,
#  'Morgan': 1,
#  'rejoins': 1,
#  'final': 1,
#  'mission': 1,
#  'undo': 1,
#  'actions': 1,
#  'creates': 1,
#  'time': 1,
#  'travel': 1,
#  'restore': 1,
#  'trillions': 1,
#  'lives': 1,
#  'universe': 1,
#  'inevitably': 1,
#  'sacrifices': 1,
#  'defeat': 1,
#  'army': 1,
#  'chooses': 1,
#  'Peter': 1,
#  'Parker': 1,
#  'successor': 1}

# %%
max_freq = max(word_freq.values())
for word in word_freq.keys():
    word_freq[word] = word_freq[word]/max_freq
word_freq
# Out:
# {'Anthony': 0.125,
#  'Edward': 0.125,
#  'Stark': 1.0,
#  'commonly': 0.25,
#  'known': 0.25,
#  'Tony': 0.125,
#  'fictional': 0.125,
#  'character': 0.25,
#  'primarily': 0.125,
#  'portrayed': 0.125,
#  'Robert': 0.125,
#  'Downey': 0.125,
#  'Jr.': 0.125,
#  'Marvel': 0.25,
#  'Cinematic': 0.125,
#  'Universe': 0.125,
#  'MCU': 0.125,
#  'media': 0.125,
#  'franchise': 0.125,
#  '—': 0.25,
#  'based': 0.125,
#  'Comics': 0.125,
#  'alias': 0.125,
#  'Iron': 0.125,
#  'Man': 0.125,
#  'initially': 0.125,
#  'depicted': 0.125,
#  'industrialist': 0.125,
#  'genius': 0.125,
#  'inventor': 0.125,
#  'playboy': 0.125,
#  'CEO': 0.125,
#  'Industries': 0.125,
#  'Initially': 0.125,
#  'chief': 0.125,
#  'weapons': 0.125,
#  'manufacturer': 0.125,
#  'U.S.': 0.125,
#  'military': 0.125,
#  'change': 0.125,
#  'heart': 0.125,
#  'redirects': 0.125,
#  'technical': 0.125,
#  'knowledge': 0.125,
#  'creation': 0.125,
#  'mechanized': 0.125,
#  'suits': 0.125,
#  'armor': 0.125,
#  'uses': 0.125,
#  'defend': 0.125,
#  'threaten': 0.125,
#  'peace': 0.125,
#  'world': 0.125,
#  'founding': 0.125,
#  'member': 0.125,
#  'leader': 0.125,
#  'Avengers': 0.5,
#  'Following': 0.125,
#  'failed': 0.125,
#  'Ultron': 0.125,
#  'Program': 0.125,
#  'internal': 0.125,
#  'conflict': 0.125,
#  'Sokovia': 0.125,
#  'Accords': 0.125,
#  'Thanos': 0.375,
#  'successfully': 0.25,
#  'erasing': 0.125,
#  'half': 0.125,
#  'life': 0.25,
#  'Blip': 0.125,
#  'retires': 0.125,
#  'marries': 0.125,
#  'Pepper': 0.125,
#  'Potts': 0.125,
#  'daughter': 0.125,
#  'named': 0.125,
#  'Morgan': 0.125,
#  'rejoins': 0.125,
#  'final': 0.125,
#  'mission': 0.125,
#  'undo': 0.125,
#  'actions': 0.125,
#  'creates': 0.125,
#  'time': 0.125,
#  'travel': 0.125,
#  'restore': 0.125,
#  'trillions': 0.125,
#  'lives': 0.125,
#  'universe': 0.125,
#  'inevitably': 0.125,
#  'sacrifices': 0.125,
#  'defeat': 0.125,
#  'army': 0.125,
#  'chooses': 0.125,
#  'Peter': 0.125,
#  'Parker': 0.125,
#  'successor': 0.125}

# %%
sent_tokens = [sent for sent in doc.sents]
sent_tokens
# Out:
# [Anthony Edward Stark, more commonly known as Tony Stark, is a fictional character primarily portrayed by Robert Downey Jr. in the Marvel Cinematic Universe (MCU) media franchise—based on the Marvel Comics character of the same name—commonly known by his alias, Iron Man.,
#  Stark is initially depicted as an industrialist, genius inventor, and playboy who is CEO of Stark Industries.,
#  Initially the chief weapons manufacturer for the U.S. military, he has a change of heart and redirects his technical knowledge into the creation of mechanized suits of armor which he uses to defend against those that would threaten peace around the world.,
#  He becomes a founding member and leader of the Avengers.,
#  Following his failed Ultron Program, the internal conflict within the Avengers due to the Sokovia Accords, and Thanos successfully erasing half of all life in the Blip, Stark retires, marries Pepper Potts, and they have a daughter named Morgan.,
#  However, Stark rejoins the Avengers on a final mission to undo Thanos' actions.,
#  He creates time travel, and the Avengers successfully restore trillions of lives across the universe.,
#  However, Stark inevitably sacrifices his life to defeat Thanos and his army.,
#  Stark chooses Peter Parker as a successor.]

# %%
sent_scores={}
for sent in sent_tokens:
    for word in sent:
        if word.text in word_freq.keys():
            if sent not in sent_scores.keys():
                sent_scores[sent] = word_freq[word.text]
                
            else:
                sent_scores[sent] += word_freq[word.text]
sent_scores
# Out:
# {Anthony Edward Stark, more commonly known as Tony Stark, is a fictional character primarily portrayed by Robert Downey Jr. in the Marvel Cinematic Universe (MCU) media franchise—based on the Marvel Comics character of the same name—commonly known by his alias, Iron Man.: 6.875,
#  Stark is initially depicted as an industrialist, genius inventor, and playboy who is CEO of Stark Industries.: 3.0,
#  Initially the chief weapons manufacturer for the U.S. military, he has a change of heart and redirects his technical knowledge into the creation of mechanized suits of armor which he uses to defend against those that would threaten peace around the world.: 2.5,
#  He becomes a founding member and leader of the Avengers.: 0.875,
#  Following his failed Ultron Program, the internal conflict within the Avengers due to the Sokovia Accords, and Thanos successfully erasing half of all life in the Blip, Stark retires, marries Pepper Potts, and they have a daughter named Morgan.: 4.625,
#  However, Stark rejoins the Avengers on a final mission to undo Thanos' actions.: 2.5,
#  He creates time travel, and the Avengers successfully restore trillions of lives across the universe.: 1.625,
#  However, Stark inevitably sacrifices his life to defeat Thanos and his army.: 2.125,
#  Stark chooses Peter Parker as a successor.: 1.5}

# %%
select_len = int(len(sent_tokens) * 0.3)
summary = nlargest(select_len, sent_scores, key=sent_scores.get)
summary
# Out:
# [Anthony Edward Stark, more commonly known as Tony Stark, is a fictional character primarily portrayed by Robert Downey Jr. in the Marvel Cinematic Universe (MCU) media franchise—based on the Marvel Comics character of the same name—commonly known by his alias, Iron Man.,
#  Following his failed Ultron Program, the internal conflict within the Avengers due to the Sokovia Accords, and Thanos successfully erasing half of all life in the Blip, Stark retires, marries Pepper Potts, and they have a daughter named Morgan.]

# %%
final_summary = [word.text for word in summary]
summary =  ' '.join(final_summary)
summary
# Out:
# 'Anthony Edward Stark, more commonly known as Tony Stark, is a fictional character primarily portrayed by Robert Downey Jr. in the Marvel Cinematic Universe (MCU) media franchise—based on the Marvel Comics character of the same name—commonly known by his alias, Iron Man. Following his failed Ultron Program, the internal conflict within the Avengers due to the Sokovia Accords, and Thanos successfully erasing half of all life in the Blip, Stark retires, marries Pepper Potts, and they have a daughter named Morgan.'

# %%
print("length of original text:",len(text.split(' ')))
print("length of summarized text:",len(summary.split(' ')))
# Out:
# length of original text: 197
# length of summarized text: 81
